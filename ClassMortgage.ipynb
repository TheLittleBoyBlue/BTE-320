# %% [markdown]
# <a href="https://colab.research.google.com/github/TheLittleBoyBlue/BTE-320/blob/main/classMortgage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Mortgage:
  def __init__(self, amount, maturity, interest):
    self.amount = amount
    self.maturity = maturity
    self.interest = interest

  def __str__(self):
    return f'Mortgage info: \n Initial loan amount: {self.amount} $\n Maturity term: {self.maturity} years\n Interest rate: {self.__interest}%'

  def get_interest(self):
    return self.interst

  def set_interest(self, newInterest):
    if newinterest >=0:
      self.interest = newInterest
    else:
      print('Interest must be non-negative!')

  def payment(self):
    B = self.amount
    n = self.maturity * 12
    r = self.__interest / 100

    return (B * (r * (1 + r) ** n) / ((1 + r) ** n - 1))

# %%
m = Mortgage(100000,30,6)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c384c0c7b6c7> in <cell line: 1>()
# ----> 1 print(m)
#
# <ipython-input-3-931d61a3cfca> in __str__(self)
#       6
#       7   def __str__(self):
# ----> 8     return f'Mortgage info: \n Initial loan amount: {self.amount} $\n Maturity term: {self.maturity} years\n Interest rate: {self.__interest}%'
#       9
#      10   def get_interest(self):
#
# AttributeError: 'Mortgage' object has no attribute '_Mortgage__interest'
